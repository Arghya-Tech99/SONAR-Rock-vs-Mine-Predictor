# %% [markdown]
# <a href="https://colab.research.google.com/github/Arghya-Tech99/SONAR-Rock-vs-Mine-Predictor/blob/Import-dependencies/Rock_vs_Mine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import the Dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split # Splits Dataset into training and testing sets
from sklearn.linear_model import LogisticRegression # Implements Logistic regression algorithm
from sklearn.metrics import accuracy_score # Evaluates performance of classification model
